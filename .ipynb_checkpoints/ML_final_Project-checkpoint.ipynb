# %% [markdown]
# Problem Statement :
# Predict heart attack likelihood in individuals aged 18–35 using demographics, lifestyle, medical history, and clinical test data to enable early diagnosis and prevention.

# %% [markdown]
# About this DataSet
#
# ** Demographics **
# - Age: Captures the age range of individuals (18–35 years).
# - Gender: Distribution among males, females, and others.
# - Region: Geographical zones (e.g., North, South, East, West, etc.).
# - Urban/Rural: Differentiates between urban and rural populations.
# - Socioeconomic Status (SES): Low, middle, or high economic tiers.
#
# ** Lifestyle Factors **
# - Smoking and Alcohol Consumption: Frequency categories (e.g., never, occasionally, regularly).
# - Dietary Preferences: Vegetarian, non-vegetarian, and vegan choices.
# - Physical Activity: Levels (sedentary, moderate, high).
# - Screen Time: Hours spent on screens per day (digital exposure).
# - Sleep Duration: Average sleep hours per night.
#
# ** Medical History **
# - Family History of Heart Disease: Presence of hereditary risk.
# - Diabetes and Hypertension: Binary indicators of chronic conditions.
# - Cholesterol Levels: Total cholesterol in mg/dL.
# BMI: Body mass index as an obesity metric.
# - Stress Levels: Low, medium, or high.
#
# ** Clinical and Test Results **
# - Blood Pressure (Sys/Dia): Systolic/diastolic pressure in mmHg.
# - Resting Heart Rate: Beats per minute at rest.
# - ECG Results: Normal or abnormal heart electrical activity.
# - Chest Pain Type: Categories of pain experienced (typical, atypical, etc.).
# - Maximum Heart Rate Achieved: During stress or exercise.
# - Exercise-Induced Angina: Whether angina is triggered by exertion.
# - Blood Oxygen Levels (SpO2%): Oxygen saturation in the bloodstream.
# - Triglyceride Levels: Fat content in the blood (mg/dL).
#
# ** Target Variable **
# - Heart Attack Likelihood: Binary target indicating the presence (Yes) or absence (No) of heart attack risk.

# %% [markdown]
# ### Importing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/heart_attack_youngsters_india.csv")
df.head()
# Out:
#    Age  Gender Region Urban/Rural     SES Smoking Status Alcohol Consumption  \
# 0   30    Male   East       Urban  Middle          Never           Regularly
# 1   24  Female   East       Urban     Low   Occasionally        Occasionally
# 2   24  Female  North       Urban     Low   Occasionally        Occasionally
# 3   27    Male   East       Urban  Middle   Occasionally               Never
# 4   21  Female   West       Rural     Low   Occasionally        Occasionally
#
#         Diet Type Physical Activity Level  Screen Time (hrs/day)  ...  \
# 0  Non-Vegetarian               Sedentary                      3  ...
# 1  Non-Vegetarian               Sedentary                     15  ...
# 2           Vegan                    High                     15  ...
# 3      Vegetarian               Sedentary                      6  ...
# 4      Vegetarian                Moderate                      4  ...
#
#    Stress Level Blood Pressure (systolic/diastolic mmHg)  \
# ...

# %% [markdown]
# ### Basic EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       10000 non-null  int64
#  1   Gender                                    10000 non-null  object
#  2   Region                                    10000 non-null  object
#  3   Urban/Rural                               10000 non-null  object
#  4   SES                                       10000 non-null  object
#  5   Smoking Status                            10000 non-null  object
#  6   Alcohol Consumption                       10000 non-null  object
#  7   Diet Type                                 10000 non-null  object
#  8   Physical Activity Level                   10000 non-null  object
#  9   Screen Time (hrs/day)                     10000 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Age                                         0
# Gender                                      0
# Region                                      0
# Urban/Rural                                 0
# SES                                         0
# Smoking Status                              0
# Alcohol Consumption                         0
# Diet Type                                   0
# Physical Activity Level                     0
# Screen Time (hrs/day)                       0
# Sleep Duration (hrs/day)                    0
# Family History of Heart Disease             0
# Diabetes                                    0
# Hypertension                                0
# Cholesterol Levels (mg/dL)                  0
# BMI (kg/m²)                                 0
# Stress Level                                0
# Blood Pressure (systolic/diastolic mmHg)    0
# Resting Heart Rate (bpm)                    0
# ECG Results                                 0
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Urban/Rural', 'SES', 'Smoking Status',
#        'Alcohol Consumption', 'Diet Type', 'Physical Activity Level',
#        'Screen Time (hrs/day)', 'Sleep Duration (hrs/day)',
#        'Family History of Heart Disease', 'Diabetes', 'Hypertension',
#        'Cholesterol Levels (mg/dL)', 'BMI (kg/m²)', 'Stress Level',
#        'Blood Pressure (systolic/diastolic mmHg)', 'Resting Heart Rate (bpm)',
#        'ECG Results', 'Chest Pain Type', 'Maximum Heart Rate Achieved',
#        'Exercise Induced Angina', 'Blood Oxygen Levels (SpO2%)',
#        'Triglyceride Levels (mg/dL)', 'Heart Attack Likelihood'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 26)

# %%
df.columns = df.columns.str.replace(r"\(.*?\)", "", regex=True).str.strip().str.replace(" ","_")
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Urban/Rural', 'SES', 'Smoking_Status',
#        'Alcohol_Consumption', 'Diet_Type', 'Physical_Activity_Level',
#        'Screen_Time', 'Sleep_Duration', 'Family_History_of_Heart_Disease',
#        'Diabetes', 'Hypertension', 'Cholesterol_Levels', 'BMI', 'Stress_Level',
#        'Blood_Pressure', 'Resting_Heart_Rate', 'ECG_Results',
#        'Chest_Pain_Type', 'Maximum_Heart_Rate_Achieved',
#        'Exercise_Induced_Angina', 'Blood_Oxygen_Levels', 'Triglyceride_Levels',
#        'Heart_Attack_Likelihood'],
#       dtype='object')

# %%
df.Heart_Attack_Likelihood.value_counts()
# Out:
# Heart_Attack_Likelihood
# No     7962
# Yes    2038
# Name: count, dtype: int64

# %%
df.select_dtypes(['int64','float64']).describe().T
# Out:
#                                count       mean         std    min    25%  \
# Age                          10000.0   26.60150    5.164239   18.0   22.0
# Screen_Time                  10000.0    7.51070    4.626578    0.0    4.0
# Sleep_Duration               10000.0    6.48960    2.289327    3.0    4.0
# Cholesterol_Levels           10000.0  199.64900   57.561902  100.0  150.0
# BMI                          10000.0   27.44190    7.223740   15.0   21.2
# Resting_Heart_Rate           10000.0   89.49340   17.318237   60.0   74.0
# Maximum_Heart_Rate_Achieved  10000.0  159.68390   35.034037  100.0  129.0
# Blood_Oxygen_Levels          10000.0   94.94073    2.883329   90.0   92.4
# Triglyceride_Levels          10000.0  275.01010  128.825994   50.0  164.0
#
#                                50%    75%    max
# Age                           27.0   31.0   35.0
# Screen_Time                    8.0   12.0   15.0
# Sleep_Duration                 6.0    8.0   10.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
cat_col = df.select_dtypes("object").columns
for col in cat_col:
    print(f"{col}: {df[col].unique()}")
# Out:
# Gender: ['Male' 'Female' 'Other']
# Region: ['East' 'North' 'West' 'North-East' 'Central' 'South']
# Urban/Rural: ['Urban' 'Rural']
# SES: ['Middle' 'Low' 'High']
# Smoking_Status: ['Never' 'Occasionally' 'Regularly']
# Alcohol_Consumption: ['Regularly' 'Occasionally' 'Never']
# Diet_Type: ['Non-Vegetarian' 'Vegan' 'Vegetarian']
# Physical_Activity_Level: ['Sedentary' 'High' 'Moderate']
# Family_History_of_Heart_Disease: ['No' 'Yes']
# Diabetes: ['No' 'Yes']
# Hypertension: ['Yes' 'No']
# Stress_Level: ['High' 'Low' 'Medium']
# Blood_Pressure: ['177.0/63.1' '137.5/110.7' '138.3/76.6' ... '120.8/81.3' '110.0/100.3'
#  '166.0/83.5']
# ECG_Results: ['Normal' 'Abnormal']
# Chest_Pain_Type: ['Non-anginal' 'Typical' 'Atypical' 'Asymptomatic']
# Exercise_Induced_Angina: ['No' 'Yes']
# Heart_Attack_Likelihood: ['No' 'Yes']

# %% [markdown]
# ### Data Cleaning and Pre-Processing

# %%
# separate Blood Pressure into Systolic and Diastolic
df["Systolic"] = df["Blood_Pressure"].str.split("/",expand = True)[0].astype("float")
df["Diastolic"] = df["Blood_Pressure"].str.split("/",expand = True)[1].astype("float64")

# %%
df.drop("Blood_Pressure",axis = 1,inplace = True)

# %%
num_col = df.select_dtypes(["int64","float64"]).columns
df[num_col].hist(figsize = (12,16),bins =20)
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Screen_Time'}>,
#         <Axes: title={'center': 'Sleep_Duration'}>],
#        [<Axes: title={'center': 'Cholesterol_Levels'}>,
#         <Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'Resting_Heart_Rate'}>],
#        [<Axes: title={'center': 'Maximum_Heart_Rate_Achieved'}>,
#         <Axes: title={'center': 'Blood_Oxygen_Levels'}>,
#         <Axes: title={'center': 'Triglyceride_Levels'}>],
#        [<Axes: title={'center': 'Systolic'}>,
#         <Axes: title={'center': 'Diastolic'}>, <Axes: >]], dtype=object)

# %%
# Select categorical columns
cal_col = df.select_dtypes("object")

num_cols = 3
num_rows = (len(cat_col) // num_cols) + (len(cat_col) % num_cols != 0)  # Calculate rows dynamically

plt.figure(figsize=(12, 4 * num_rows))

# Plot categorical variables against Heart_Attack_Likelihood
for i, col in enumerate(cat_col, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)

# Adjust layout and show the plots after the loop
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5aa65e45058e> in <cell line: 0>()
#      10 for i, col in enumerate(cat_col, 1):
#      11     plt.subplot(num_rows, num_cols, i)  # Adjust the layout for the number of plots
# ---> 12     sns.countplot(x=col, data=df)
#      13     plt.title(f'Distribution of {col}')
#      14     plt.xticks(rotation=45)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# ...

# %%
num_cols = 3
num_rows = (len(cat_col) // num_cols) + (len(cat_col) % num_cols != 0)  # Calculate rows dynamically

plt.figure(figsize=(12, 4 * num_rows))

# Plot categorical variables against Heart_Attack_Likelihood
for i, col in enumerate(num_col, 1):
    plt.subplot(num_rows, num_cols, i)  # Adjust the layout for the number of plots
    sns.kdeplot(x=df[col], shade=True)
    plt.title(f'KDE Plot of {col}')
    plt.xticks(rotation=45)

# Adjust layout and show the plots after the loop
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-9c0dc8237b73>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[col], shade=True)
# <ipython-input-16-9c0dc8237b73>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[col], shade=True)
# <ipython-input-16-9c0dc8237b73>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[col], shade=True)
# <ipython-input-16-9c0dc8237b73>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[col], shade=True)
# <ipython-input-16-9c0dc8237b73>:9: FutureWarning:
# ...

# %%
num_col = df.select_dtypes(["int64","float64"])
num_col.corr()
# Out:
#                                   Age  Screen_Time  Sleep_Duration  \
# Age                          1.000000    -0.006190       -0.006987
# Screen_Time                 -0.006190     1.000000       -0.004007
# Sleep_Duration              -0.006987    -0.004007        1.000000
# Cholesterol_Levels          -0.015980     0.026748        0.018108
# BMI                         -0.002449     0.001364       -0.006385
# Resting_Heart_Rate           0.001862     0.020419       -0.005748
# Maximum_Heart_Rate_Achieved  0.000003     0.012493       -0.001075
# Blood_Oxygen_Levels          0.007576     0.008492        0.009137
# Triglyceride_Levels          0.005791    -0.009526       -0.001890
# Systolic                    -0.000479    -0.017568       -0.022202
# Diastolic                   -0.001294    -0.013482       -0.005112
#
#                              Cholesterol_Levels       BMI  Resting_Heart_Rate  \
# Age                                   -0.015980 -0.002449            0.001862
# ...

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data = num_col.corr(), annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
cat_col = df.select_dtypes("object").columns

# Calculate number of rows and columns for the subplots grid
num_cols = 3
num_rows = (len(cat_col) // num_cols) + (len(cat_col) % num_cols != 0)  # Calculate rows dynamically

plt.figure(figsize=(12, 4 * num_rows))

# Plot categorical variables against Heart_Attack_Likelihood
for i, col in enumerate(cat_col, 1):
    plt.subplot(num_rows, num_cols, i)  # Adjust the layout for the number of plots
    sns.countplot(x=col, hue='Heart_Attack_Likelihood', data=df)
    plt.title(f'{col} vs Heart_Attack_Likelihood')
    plt.xticks(rotation=45)

# Adjust layout and show the plots after the loop
plt.tight_layout()
plt.show()

# %%
# Select numerical columns
num_col = df.select_dtypes(["int64", "float64"]).columns

# Filter outliers for all numerical columns
filtered_data = df.copy()
for col in num_col:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    filtered_data = filtered_data[(filtered_data[col] >= lower_bound) & (filtered_data[col] <= upper_bound)]

# Melt the data for a combined boxplot
melted_data = filtered_data[num_col].melt(var_name="Columns", value_name="Values")

# Plot the combined boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=melted_data, x="Columns", y="Values")
plt.title("Box Plots of Numerical Columns (Outliers Removed)", fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Check if outliers exist in the filtered data
for col in num_col:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}: {len(outliers)} outliers")
# Out:
# Age: 0 outliers
# Screen_Time: 0 outliers
# Sleep_Duration: 0 outliers
# Cholesterol_Levels: 0 outliers
# BMI: 0 outliers
# Resting_Heart_Rate: 0 outliers
# Maximum_Heart_Rate_Achieved: 0 outliers
# Blood_Oxygen_Levels: 0 outliers
# Triglyceride_Levels: 0 outliers
# Systolic: 0 outliers
# Diastolic: 0 outliers

# %%
# Check class distribution of Heart_Attack_Likelihood
plt.figure(figsize=(8, 6))
sns.countplot(x='Heart_Attack_Likelihood', data=df)
plt.title('Distribution of Heart Attack Likelihood')
plt.show()

# Percentage of each class
df['Heart_Attack_Likelihood'].value_counts(normalize=True)
# Out:
# Heart_Attack_Likelihood
# No     0.7962
# Yes    0.2038
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# Make a copy of the data
X = df.drop(columns=['Heart_Attack_Likelihood'])
y = df['Heart_Attack_Likelihood']

# Encode categorical columns
cat_cols = X.select_dtypes(include='object').columns
encoder = LabelEncoder()

# Apply Label Encoding to categorical features
for col in cat_cols:
    X[col] = encoder.fit_transform(X[col])

# Ensure the target variable is also encoded if necessary
y = encoder.fit_transform(y)

# %%
from sklearn.preprocessing import LabelEncoder

# Drop the target variable from the features
X = df.drop(columns=['Heart_Attack_Likelihood'])
y = df['Heart_Attack_Likelihood']

# Identify categorical columns
cat_cols = X.select_dtypes(include=['object']).columns

# Encode categorical columns with LabelEncoder
encoder = LabelEncoder()
for col in cat_cols:
    X[col] = encoder.fit_transform(X[col])

# Encode the target variable as well (if not numeric)
if y.dtype == 'object':
    y = encoder.fit_transform(y)

# %%
print(X.dtypes)  # All columns should now be numeric
print(type(y))   # Check the type of y
print(y.dtype)   # Check the data type of y
# Out:
# Age                                  int64
# Gender                               int64
# Region                               int64
# Urban/Rural                          int64
# SES                                  int64
# Smoking_Status                       int64
# Alcohol_Consumption                  int64
# Diet_Type                            int64
# Physical_Activity_Level              int64
# Screen_Time                          int64
# Sleep_Duration                       int64
# Family_History_of_Heart_Disease      int64
# Diabetes                             int64
# Hypertension                         int64
# Cholesterol_Levels                   int64
# BMI                                float64
# Stress_Level                         int64
# Resting_Heart_Rate                   int64
# ECG_Results                          int64
# Chest_Pain_Type                      int64
# Maximum_Heart_Rate_Achieved          int64
# Exercise_Induced_Angina              int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# Identify object columns that need encoding
object_cols = ['Family_History_of_Heart_Disease', 'Diabetes', 'Hypertension', 'Exercise_Induced_Angina']

# Encode these columns using LabelEncoder
for col in object_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# Verify that all columns are now numeric
print(df.dtypes)

# Split features (X) and target (y)
X = df.drop('Heart_Attack_Likelihood', axis=1)
y = df['Heart_Attack_Likelihood']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE to the training set
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Verify the new class distribution
from collections import Counter
print("Original dataset class distribution:", Counter(y_train))
print("After SMOTE class distribution:", Counter(y_train_smote))
# Out:
# Age                                  int64
# Gender                               int64
# Region                               int64
# Urban/Rural                          int64
# SES                                  int64
# Smoking_Status                       int64
# Alcohol_Consumption                  int64
# Diet_Type                            int64
# Physical_Activity_Level              int64
# Screen_Time                          int64
# Sleep_Duration                       int64
# Family_History_of_Heart_Disease      int64
# Diabetes                             int64
# Hypertension                         int64
# Cholesterol_Levels                   int64
# BMI                                float64
# Stress_Level                         int64
# Resting_Heart_Rate                   int64
# ECG_Results                          int64
# Chest_Pain_Type                      int64
# Maximum_Heart_Rate_Achieved          int64
# Exercise_Induced_Angina              int64
# ...

# %% [markdown]
# ### Model

# %%
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Define a combined objective function to optimize KNN, Logistic Regression, and SVM
def objective(trial):
    # Choose the model type
    model_type = trial.suggest_categorical('model_type', ['KNN', 'Logistic Regression', 'SVM'])

    # For KNN: tune n_neighbors and weights
    if model_type == 'KNN':
        n_neighbors = trial.suggest_int('n_neighbors', 1, 30)
        weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
        model = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights))

    # For Logistic Regression: tune C and solver
    elif model_type == 'Logistic Regression':
        C = trial.suggest_loguniform('C', 1e-5, 1e5)
        solver = trial.suggest_categorical('solver', ['liblinear', 'saga'])
        model = make_pipeline(StandardScaler(), LogisticRegression(C=C, solver=solver))

    # For SVM: tune C, kernel, and gamma
    elif model_type == 'SVM':
        C = trial.suggest_loguniform('C', 1e-5, 1e5)
        kernel = trial.suggest_categorical('kernel', ['linear', 'rbf'])
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])
        model = make_pipeline(StandardScaler(), SVC(C=C, kernel=kernel, gamma=gamma))

    # Perform cross-validation and return the mean accuracy
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
    return score.mean()

# Study and optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Display best model and hyperparameters
print("Best Model Type:", study.best_params['model_type'])
print("Best Parameters:", {k: v for k, v in study.best_params.items() if k != 'model_type'})
print("Best Accuracy:", study.best_value)
# Out:
# [I 2025-01-27 07:15:00,660] A new study created in memory with name: no-name-06fb8b5b-48c7-40aa-b451-db6531eecf44
# <ipython-input-39-0b2e1e1abcdc>:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# [I 2025-01-27 07:15:38,959] Trial 0 finished with value: 0.6957142857142857 and parameters: {'model_type': 'SVM', 'C': 366.9359549446379, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.6957142857142857.
# <ipython-input-39-0b2e1e1abcdc>:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import optuna

# KNN Objective function
def objective_knn(trial):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Hyperparameter tuning for KNN
    n_neighbors = trial.suggest_int('n_neighbors', 1, 20)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    p = trial.suggest_int('p', 1, 2)  # p=1 is Manhattan distance, p=2 is Euclidean distance

    # Initialize KNN model
    model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)

    # Train the model
    model.fit(X_train, y_train)

    # Make predictions and evaluate accuracy
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy  # Optimize for accuracy

# %%
from sklearn.linear_model import LogisticRegression

# Logistic Regression Objective function
def objective_logreg(trial):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Hyperparameter tuning for Logistic Regression
    C = trial.suggest_loguniform('C', 1e-5, 1e5)  # Regularization strength
    solver = trial.suggest_categorical('solver', ['liblinear', 'lbfgs', 'saga'])
    max_iter = trial.suggest_int('max_iter', 100, 1000)  # Maximum number of iterations

    # Initialize Logistic Regression model
    model = LogisticRegression(C=C, solver=solver, max_iter=max_iter, random_state=42)

    # Train the model
    model.fit(X_train, y_train)

    # Make predictions and evaluate accuracy
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy  # Optimize for accuracy

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Cross-validation with K-Folds for model evaluation
def objective_kfold(trial):
    model_choice = trial.suggest_categorical('model', ['knn', 'logreg'])

    if model_choice == 'knn':
        # KNN Hyperparameters
        n_neighbors = trial.suggest_int('n_neighbors', 1, 20)
        weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
        p = trial.suggest_int('p', 1, 2)  # p=1 is Manhattan distance, p=2 is Euclidean distance
        model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)
    else:
        # Logistic Regression Hyperparameters
        C = trial.suggest_loguniform('C', 1e-5, 1e5)
        solver = trial.suggest_categorical('solver', ['liblinear', 'lbfgs', 'saga'])
        max_iter = trial.suggest_int('max_iter', 100, 1000)
        model = LogisticRegression(C=C, solver=solver, max_iter=max_iter)

    # Cross-validation score (3-fold CV)
    score = cross_val_score(model, X, y, n_jobs=-1, cv=3)  # Use 3-fold cross-validation
    return score.mean()  # Return mean cross-validation score

# %%
# Create an Optuna study to maximize the objective function
study = optuna.create_study(direction='maximize')

# Optimize the KNN model
study.optimize(objective_knn, n_trials=50)

# Print the best hyperparameters and the best accuracy score for KNN
print(f"Best trial (KNN): {study.best_trial.params}")
print(f"Best accuracy (KNN): {study.best_value}")

# %%
study.optimize(objective_logreg, n_trials=20)

print(f"Best trial (Logistic Regression): {study.best_trial.params}")
print(f"Best accuracy (Logistic Regression): {study.best_value}")

# %%
df.columns

# %%
df.Heart_Attack_Likelihood.value_counts()

# %%
# Get best hyperparameters from the study
best_params = study.best_trial.params

# Choose the model type based on the best parameters
if 'n_neighbors' in best_params:
    # Train KNN with the best hyperparameters
    final_model = KNeighborsClassifier(
        n_neighbors=best_params['n_neighbors'],
        weights=best_params['weights'],
        p=best_params['p']
    )
else:
    # Train Logistic Regression with the best hyperparameters
    final_model = LogisticRegression(
        C=best_params['C'],
        solver=best_params['solver'],
        max_iter=best_params['max_iter']
    )

# Train the final model
final_model.fit(X_train, y_train)

# Evaluate the final model on the test set
y_pred_final = final_model.predict(X_test)
final_accuracy = accuracy_score(y_test, y_pred_final)
print(f"Final Model Accuracy: {final_accuracy}")
